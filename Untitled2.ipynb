# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve,confusion_matrix,accuracy_score, auc

from sklearn.metrics import precision_recall_fscore_support, f1_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from tensorflow import keras
from keras import Sequential
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.layers import Conv1D, MaxPool1D
from keras.optimizers import Adam
from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc

import os


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing, metrics
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from keras import backend as K
from keras.models import Model
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from sklearn.utils import shuffle

import imblearn
from imblearn.over_sampling import KMeansSMOTE, SMOTE

from sklearn.model_selection import StratifiedKFold

import time 

start_time = time.time()

# %%
df = pd.read_csv('/content/creditcard.csv')
#check on the size of the dataframe

from sklearn.utils import shuffle
df= shuffle(df)

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
df.describe()
# Out:
#               Time            V1            V2            V3            V4  \
# count  43664.00000  43664.000000  43664.000000  43664.000000  43664.000000
# mean   26888.25284     -0.233273      0.031606      0.700508      0.191731
# std    12814.99066      1.881487      1.614103      1.524287      1.407338
# min        0.00000    -56.407510    -72.715728    -32.454198     -5.172595
# 25%    18719.75000     -0.980241     -0.538882      0.225681     -0.715653
# 50%    31883.00000     -0.244783      0.091807      0.804944      0.190472
# 75%    36950.00000      1.158119      0.740709      1.437905      1.071096
# max    41600.00000      1.960497     17.930550      4.101716     16.491217
#
#                  V5            V6            V7            V8            V9  \
# count  43664.000000  43664.000000  43664.000000  43664.000000  43664.000000
# mean      -0.243618      0.099239     -0.117611      0.051499      0.173603
# std        1.409001      1.310495      1.272765      1.214443      1.226176
# min      -42.147898    -26.160506    -26.548144    -41.484823     -8.507059
# 25%       -0.848251     -0.637897     -0.599128     -0.149257     -0.579444
# 50%       -0.277415     -0.155863     -0.072568      0.053267      0.053757
# 75%        0.290816      0.486612      0.431337      0.322613      0.881798
# max       34.801666     22.529298     36.677268     20.007208     10.392889
#
#        ...           V21           V22           V23           V24  \
# count  ...  43664.000000  43664.000000  43664.000000  43664.000000
# mean   ...     -0.026792     -0.110075     -0.039981      0.009712
# std    ...      0.739609      0.637124      0.568360      0.592318
# min    ...    -20.262054     -8.593642    -26.751119     -2.836627
# 25%    ...     -0.233410     -0.530920     -0.179112     -0.321968
# 50%    ...     -0.072254     -0.084865     -0.051512      0.062302
# 75%    ...      0.104877      0.302064      0.077031      0.401497
# max    ...     22.614889      5.805795     17.297845      4.014444
#
#                 V25           V26           V27           V28        Amount  \
# count  43664.000000  43664.000000  43663.000000  43663.000000  43663.000000
# mean       0.136448      0.022633      0.006871      0.005107     90.313927
# std        0.437462      0.503349      0.390445      0.342269    238.441952
# min       -7.495741     -1.438650     -8.567638     -9.617915      0.000000
# 25%       -0.128037     -0.329466     -0.063372     -0.006848      7.570000
# 50%        0.175968     -0.066830      0.008647      0.021761     24.890000
# 75%        0.421923      0.303412      0.084707      0.076353     81.555000
# max        5.525093      3.517346     11.135740     33.847808   7879.420000
#
#               Class
# count  43663.000000
# mean       0.003069
# std        0.055314
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
df['V7'] = df['V7'].replace(np.nan, 0)
df['V8'] = df['V8'].replace(np.nan, 0)
df['V9'] = df['V9'].replace(np.nan, 0)
df['V10'] = df['V10'].replace(np.nan, 0)
df['V11'] = df['V11'].replace(np.nan, 0)
df['V12'] = df['V12'].replace(np.nan, 0)
df['V13'] = df['V13'].replace(np.nan, 0)
df['V14'] = df['V14'].replace(np.nan, 0)
df['V15'] = df['V15'].replace(np.nan, 0)
df['V16'] = df['V16'].replace(np.nan, 0)
df['V17'] = df['V17'].replace(np.nan, 0)
df['V18'] = df['V18'].replace(np.nan, 0)
df['V19'] = df['V19'].replace(np.nan, 0)
df['V20'] = df['V20'].replace(np.nan, 0)
df['V21'] = df['V21'].replace(np.nan, 0)
df['V22'] = df['V22'].replace(np.nan, 0)
df['V23'] = df['V23'].replace(np.nan, 0)
df['V24'] = df['V24'].replace(np.nan, 0)
df['V25'] = df['V25'].replace(np.nan, 0)
df['V26'] = df['V26'].replace(np.nan, 0)
df['V27'] = df['V27'].replace(np.nan, 0)
df['V28'] = df['V28'].replace(np.nan, 0)
df['Amount'] = df['Amount'].replace(np.nan, 0)
df['Class'] = df['Class'].replace(np.nan, 0)

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
X = df.drop('Class',axis=1).values
y = df['Class'].values

# %%
X -= X.min(axis=0)
X /= X.max(axis=0)

# %%
#Separation of data into training & test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (30564, 30)
# Number transactions y_train dataset:  (30564,)
# Number transactions X_test dataset:  (13100, 30)
# Number transactions y_test dataset:  (13100,)

# %%
nb_epoch = 20
#batch_size = 256
input_dim = X.shape[1] #num of columns, 30
encoding_dim_1 = 27
encoding_dim_2 = 24
encoding_dim_3 = 21
hidden_dim = 15
learning_rate = 1e-7




#Cross_Validate

kf = StratifiedKFold(4, shuffle = True, random_state=42) # Use for Kfold Validation


tn_summary=[]
fp_summary=[]
fn_summary=[]
tp_summary=[]

def Average(lst): 
    return sum(lst) / len(lst)

fold = 0

for train, test in kf.split(X,y):
    np.any(np.isnan(train))
    np.all(np.isfinite(train))
    np.any(np.isnan(test))
    np.all(np.isfinite(test))
    fold +=1
    print(f"Fold #{fold}")
    
    x_train = X[train]
    y_train = y[train]
    x_test = X[test]
    y_test = y[test]

    
    scaler = preprocessing.StandardScaler()

    x_train, x_test = scaler.fit_transform(x_train), scaler.fit_transform(x_test) 
    k=1
    sm = SMOTE()
    #sm=SMOTE(kind='regular',k_neighbors=2)


    #X_res_train, y_train_res = sm.fit_resample(x_train, y_train)
    X_res_train, y_train_res = sm.fit_resample(x_train, y_train.ravel())

    print('After OverSampling, the shape of train_X: {}'.format(X_res_train.shape))
    print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

    print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
    print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
    
    sm=KMeansSMOTE()
    
    X_res_train, y_train_res = sm.fit_resample(X_res_train, y_train_res.ravel())

    print('After OverSampling, the shape of train_X: {}'.format(X_res_train.shape))
    print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

    print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
    print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
    
    
    input_layer = Input(shape=(input_dim, ))

    encoder = Dense(encoding_dim_1, activation="elu", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
    encoder = Dense(encoding_dim_2, activation = "elu")(encoder)
    encoder = Dense(encoding_dim_3, activation = "elu")(encoder)

    encoder = Dense(hidden_dim, activation="elu")(encoder)

    decoder = Dense(encoding_dim_3, activation = "elu")(encoder)
    decoder = Dense(encoding_dim_2, activation = "elu")(decoder)
    decoder = Dense(encoding_dim_1, activation = "elu")(decoder)
    decoder = Dense(input_dim, activation="elu")(decoder)

    autoencoder = Model(inputs=input_layer, outputs=decoder)
    
    # Create the autoencoder model
    autoencoder = Model(input_layer, decoder)
    #Compile the autoencoder model
    autoencoder.compile(optimizer='adam',loss='mean_squared_error')
    #Fit to train set and save to hist_auto for plotting purposes
    hist_auto = autoencoder.fit(x_train, x_train,epochs=150,shuffle=True,validation_data=(x_test, x_test))
    
    
    # Summarize history for loss
    plt.figure()
    plt.plot(hist_auto.history['loss'])
    plt.plot(hist_auto.history['val_loss'])
    plt.title('Autoencoder model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    # Create a separate model (encoder) in order to make encodings (first part of the autoencoder model)
    encoder_model = Model(input_layer, encoder)
    # Create a placeholder for an encoded input
    encoded_input = Input(shape=(hidden_dim,))
    
    #Encode data set from above using the encoder
    encoded_train_x = encoder_model.predict(x_train)
    encoded_test_x = encoder_model.predict(x_test)
    #Reshape data for the CNN model
    encoded_train_x = encoded_train_x.reshape(encoded_train_x.shape[0],encoded_train_x.shape[1], 1)
    encoded_test_x = encoded_test_x.reshape(encoded_test_x.shape[0], encoded_test_x.shape[1], 1)
    encoded_train_x.shape

    epochs = 50
    model = Sequential()
    model.add(Conv1D(32, 2, activation='relu', input_shape = encoded_train_x[1].shape))
    model.add(BatchNormalization())
    model.add(MaxPool1D(2))
    model.add(Dropout(0.2))

    model.add(Conv1D(64, 2, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPool1D(2))
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=Adam(lr=0.0001), loss = 'binary_crossentropy',metrics=['accuracy'])
    history = model.fit(encoded_train_x, y_train,epochs=epochs,validation_data=(encoded_test_x, y_test), verbose=1)
    
    # Summarize history for loss
    plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Encoded model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    predictions_CNN_prob = model.predict(encoded_test_x)
    predictions_CNN_prob = predictions_CNN_prob[:,0]
    predictions_CNN_01 = np.where(predictions_CNN_prob > 0.5, 1, 0) #Turn probability to 0-1 binary output
    #Print accuracy
    acc_CNN = accuracy_score(y_test, predictions_CNN_01)
    print('Overall accuracy of SMOTE - Deep Autoencoder - Convolutional Neural Network model:', acc_CNN)
    #Print Area Under Curve
    false_positive_rate, recall, thresholds = roc_curve(y_test,predictions_CNN_prob)
    roc_auc = auc(false_positive_rate, recall)
    plt.figure()
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1], [0,1], 'r--')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.0])
    plt.ylabel('Recall')
    plt.xlabel('Fall-out (1-Specificity)')
    plt.show()
    #Print Confusion Matrix
    cm = confusion_matrix(y_test, predictions_CNN_01)
    labels = ['No Default', 'Default']
    plt.figure(figsize=(8,6))
    sns.heatmap(cm,xticklabels=labels, yticklabels=labels, annot=True, fmt='d',cmap="Blues", vmin = 0.2);
    plt.title('Confusion Matrix')
    plt.ylabel('True Class')
    plt.xlabel('Predicted Class')
    plt.show()
    
    print("AUC(ROC): " + str(metrics.roc_auc_score(y_test, predictions_CNN_01)))
    print("Precision: " + str(metrics.precision_score(y_test, predictions_CNN_01)))
    print("Recall: " + str(metrics.recall_score(y_test, predictions_CNN_01)))
    print("F1 score: " + str(metrics.f1_score(y_test, predictions_CNN_01)))

    tn, fp, fn, tp = metrics.confusion_matrix(y_test, predictions_CNN_01).ravel()

    print("False positives: " + str(fp))
    print("True positives: " + str(tp))
    print("False negatives: " + str(fn))
    print("True negatives: " + str(tn))
    
    tn_summary.append(tn)
    fp_summary.append(fp)
    fn_summary.append(fn)
    tp_summary.append(tp)
# Out:
# Fold #1
# After OverSampling, the shape of train_X: (65294, 30)
# After OverSampling, the shape of train_y: (65294,)
#
# After OverSampling, counts of label '1': 32647
# After OverSampling, counts of label '0': 32647
# After OverSampling, the shape of train_X: (65294, 30)
# After OverSampling, the shape of train_y: (65294,)
#
# After OverSampling, counts of label '1': 32647
# After OverSampling, counts of label '0': 32647
# Epoch 1/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.6510 - val_loss: 0.5499
# Epoch 2/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.4889 - val_loss: 0.4635
# Epoch 3/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.4251 - val_loss: 0.4263
# Epoch 4/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3991 - val_loss: 0.3963
# Epoch 5/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3764 - val_loss: 0.3741
# Epoch 6/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3607 - val_loss: 0.3654
# Epoch 7/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3509 - val_loss: 0.3488
# Epoch 8/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3425 - val_loss: 0.3381
# Epoch 9/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.3341 - val_loss: 0.3265
# Epoch 10/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3272 - val_loss: 0.3360
# Epoch 11/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.3234 - val_loss: 0.3159
# Epoch 12/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.3162 - val_loss: 0.3216
# Epoch 13/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3150 - val_loss: 0.3046
# Epoch 14/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3075 - val_loss: 0.3028
# Epoch 15/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3068 - val_loss: 0.3045
# Epoch 16/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3035 - val_loss: 0.3028
# Epoch 17/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3012 - val_loss: 0.2959
# Epoch 18/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2987 - val_loss: 0.2947
# Epoch 19/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2976 - val_loss: 0.2962
# Epoch 20/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2952 - val_loss: 0.2899
# Epoch 21/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2949 - val_loss: 0.2875
# Epoch 22/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2920 - val_loss: 0.2918
# Epoch 23/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2933 - val_loss: 0.2873
# Epoch 24/150
# 1024/1024 [==============================] - 5s 4ms/step - loss: 0.2900 - val_loss: 0.2912
# Epoch 25/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2902 - val_loss: 0.2867
# Epoch 26/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2884 - val_loss: 0.2856
# Epoch 27/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2865 - val_loss: 0.2916
# Epoch 28/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2907 - val_loss: 0.2823
# Epoch 29/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2861 - val_loss: 0.2790
# Epoch 30/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2841 - val_loss: 0.2805
# Epoch 31/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2839 - val_loss: 0.2811
# Epoch 32/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2845 - val_loss: 0.2801
# Epoch 33/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2858 - val_loss: 0.2776
# Epoch 34/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2831 - val_loss: 0.2792
# Epoch 35/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2807 - val_loss: 0.2776
# Epoch 36/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2817 - val_loss: 0.2760
# Epoch 37/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2804 - val_loss: 0.2879
# Epoch 38/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2822 - val_loss: 0.2766
# Epoch 39/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2789 - val_loss: 0.2802
# Epoch 40/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2779 - val_loss: 0.2731
# Epoch 41/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2789 - val_loss: 0.2806
# Epoch 42/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2774 - val_loss: 0.2743
# Epoch 43/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2778 - val_loss: 0.2751
# Epoch 44/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2774 - val_loss: 0.2732
# Epoch 45/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2773 - val_loss: 0.2750
# Epoch 46/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2771 - val_loss: 0.2728
# Epoch 47/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2784 - val_loss: 0.2728
# Epoch 48/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2755 - val_loss: 0.2720
# Epoch 49/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2757 - val_loss: 0.2770
# Epoch 50/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2760 - val_loss: 0.3100
# Epoch 51/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2765 - val_loss: 0.2727
# Epoch 52/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2755 - val_loss: 0.2809
# Epoch 53/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2749 - val_loss: 0.2707
# Epoch 54/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2758 - val_loss: 0.2714
# Epoch 55/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2751 - val_loss: 0.2783
# Epoch 56/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2749 - val_loss: 0.2705
# Epoch 57/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2740 - val_loss: 0.2723
# Epoch 58/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2727 - val_loss: 0.2753
# Epoch 59/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2748 - val_loss: 0.2695
# Epoch 60/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2729 - val_loss: 0.2709
# Epoch 61/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2730 - val_loss: 0.2839
# Epoch 62/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2737 - val_loss: 0.2721
# Epoch 63/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2726 - val_loss: 0.2684
# Epoch 64/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2731 - val_loss: 0.2692
# Epoch 65/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2733 - val_loss: 0.2728
# Epoch 66/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2719 - val_loss: 0.2692
# Epoch 67/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2722 - val_loss: 0.2766
# Epoch 68/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2803 - val_loss: 0.2766
# Epoch 69/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2740 - val_loss: 0.2687
# Epoch 70/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2706 - val_loss: 0.2666
# Epoch 71/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2720 - val_loss: 0.2677
# Epoch 72/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2720 - val_loss: 0.2707
# Epoch 73/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2704 - val_loss: 0.2700
# Epoch 74/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2714 - val_loss: 0.2665
# Epoch 75/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2692 - val_loss: 0.2707
# Epoch 76/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2698 - val_loss: 0.2651
# Epoch 77/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2702 - val_loss: 0.2827
# Epoch 78/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2686 - val_loss: 0.2648
# Epoch 79/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2688 - val_loss: 0.2690
# Epoch 80/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2703 - val_loss: 0.2948
# Epoch 81/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2689 - val_loss: 0.2640
# Epoch 82/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2677 - val_loss: 0.2691
# Epoch 83/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2680 - val_loss: 0.2638
# Epoch 84/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2683 - val_loss: 0.2640
# Epoch 85/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2689 - val_loss: 0.2671
# Epoch 86/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2737 - val_loss: 0.2643
# Epoch 87/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2674 - val_loss: 0.2630
# Epoch 88/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2678 - val_loss: 0.2658
# Epoch 89/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2689 - val_loss: 0.2650
# Epoch 90/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2666 - val_loss: 0.2774
# Epoch 91/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2680 - val_loss: 0.2616
# Epoch 92/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2676 - val_loss: 0.2630
# Epoch 93/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2676 - val_loss: 0.2689
# Epoch 94/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2663 - val_loss: 0.2633
# Epoch 95/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2669 - val_loss: 0.2634
# Epoch 96/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2667 - val_loss: 0.2639
# Epoch 97/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2654 - val_loss: 0.2654
# Epoch 98/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2675 - val_loss: 0.2650
# Epoch 99/150
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.2671 - val_loss: 0.2623
# Epoch 100/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2663 - val_loss: 0.2652
# Epoch 101/150
# 1024/1024 [==============================] - 5s 4ms/step - loss: 0.2656 - val_loss: 0.2654
# Epoch 102/150
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.2669 - val_loss: 0.2634
# Epoch 103/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2662 - val_loss: 0.2648
# Epoch 104/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2667 - val_loss: 0.2623
# Epoch 105/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2651 - val_loss: 0.2786
# Epoch 106/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2657 - val_loss: 0.2611
# Epoch 107/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2638 - val_loss: 0.2662
# Epoch 108/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2655 - val_loss: 0.2617
# Epoch 109/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2660 - val_loss: 0.2621
# Epoch 110/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2650 - val_loss: 0.2602
# Epoch 111/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2643 - val_loss: 0.2624
# Epoch 112/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2646 - val_loss: 0.2682
# Epoch 113/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2647 - val_loss: 0.2605
# Epoch 114/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2650 - val_loss: 0.2624
# Epoch 115/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2641 - val_loss: 0.2627
# Epoch 116/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2658 - val_loss: 0.2680
# Epoch 117/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2639 - val_loss: 0.2637
# Epoch 118/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2655 - val_loss: 0.2618
# Epoch 119/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2650 - val_loss: 0.2670
# Epoch 120/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2632 - val_loss: 0.2643
# Epoch 121/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2640 - val_loss: 0.2635
# Epoch 122/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2644 - val_loss: 0.2620
# Epoch 123/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2641 - val_loss: 0.2628
# Epoch 124/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2646 - val_loss: 0.2596
# Epoch 125/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2631 - val_loss: 0.2621
# Epoch 126/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2657 - val_loss: 0.2601
# Epoch 127/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2629 - val_loss: 0.2598
# Epoch 128/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2643 - val_loss: 0.2630
# Epoch 129/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2623 - val_loss: 0.2614
# Epoch 130/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2637 - val_loss: 0.2611
# Epoch 131/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2625 - val_loss: 0.2610
# Epoch 132/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2625 - val_loss: 0.2613
# Epoch 133/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2633 - val_loss: 0.2638
# Epoch 134/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2625 - val_loss: 0.2594
# Epoch 135/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2619 - val_loss: 0.2756
# Epoch 136/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2645 - val_loss: 0.2610
# Epoch 137/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2619 - val_loss: 0.2600
# Epoch 138/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2616 - val_loss: 0.2588
# Epoch 139/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2620 - val_loss: 0.2619
# Epoch 140/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2635 - val_loss: 0.2667
# Epoch 141/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2621 - val_loss: 0.2625
# Epoch 142/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2622 - val_loss: 0.2569
# Epoch 143/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2626 - val_loss: 0.2601
# Epoch 144/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2622 - val_loss: 0.2595
# Epoch 145/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2613 - val_loss: 0.2579
# Epoch 146/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2621 - val_loss: 0.2661
# Epoch 147/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2611 - val_loss: 0.2573
# Epoch 148/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2615 - val_loss: 0.2633
# Epoch 149/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2619 - val_loss: 0.2608
# Epoch 150/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2616 - val_loss: 0.2602
# 1024/1024 [==============================] - 1s 1ms/step
# 342/342 [==============================] - 0s 1ms/step
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.4237 - accuracy: 0.8494 - val_loss: 0.0535 - val_accuracy: 0.9964
# Epoch 2/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0585 - accuracy: 0.9893 - val_loss: 0.0200 - val_accuracy: 0.9964
# Epoch 3/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0354 - accuracy: 0.9942 - val_loss: 0.0119 - val_accuracy: 0.9975
# Epoch 4/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0243 - accuracy: 0.9955 - val_loss: 0.0102 - val_accuracy: 0.9979
# Epoch 5/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0203 - accuracy: 0.9966 - val_loss: 0.0098 - val_accuracy: 0.9980
# Epoch 6/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0179 - accuracy: 0.9969 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 7/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0168 - accuracy: 0.9969 - val_loss: 0.0067 - val_accuracy: 0.9984
# Epoch 8/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0150 - accuracy: 0.9967 - val_loss: 0.0069 - val_accuracy: 0.9985
# Epoch 9/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0130 - accuracy: 0.9971 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 10/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0121 - accuracy: 0.9977 - val_loss: 0.0059 - val_accuracy: 0.9985
# Epoch 11/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 12/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.0048 - val_accuracy: 0.9985
# Epoch 13/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.0051 - val_accuracy: 0.9987
# Epoch 14/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.0050 - val_accuracy: 0.9988
# Epoch 15/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 16/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0053 - val_accuracy: 0.9988
# Epoch 17/50
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0041 - val_accuracy: 0.9986
# Epoch 18/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9987
# Epoch 19/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 20/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9987
# Epoch 21/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 22/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 23/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0043 - val_accuracy: 0.9989
# Epoch 24/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0040 - val_accuracy: 0.9990
# Epoch 25/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9988
# Epoch 26/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0040 - val_accuracy: 0.9988
# Epoch 27/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0036 - val_accuracy: 0.9989
# Epoch 28/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0037 - val_accuracy: 0.9990
# Epoch 29/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 30/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0036 - val_accuracy: 0.9990
# Epoch 31/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0033 - val_accuracy: 0.9990
# Epoch 32/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0035 - val_accuracy: 0.9990
# Epoch 33/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 34/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0033 - val_accuracy: 0.9989
# Epoch 35/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0033 - val_accuracy: 0.9988
# Epoch 36/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 37/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0034 - val_accuracy: 0.9990
# Epoch 38/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0034 - val_accuracy: 0.9991
# Epoch 39/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0033 - val_accuracy: 0.9988
# Epoch 40/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0033 - val_accuracy: 0.9988
# Epoch 41/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0032 - val_accuracy: 0.9993
# Epoch 42/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0034 - val_accuracy: 0.9991
# Epoch 43/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0032 - val_accuracy: 0.9990
# Epoch 44/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0031 - val_accuracy: 0.9990
# Epoch 45/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 46/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0030 - val_accuracy: 0.9993
# Epoch 47/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0027 - val_accuracy: 0.9993
# Epoch 48/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0026 - val_accuracy: 0.9992
# Epoch 49/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0027 - val_accuracy: 0.9989
# Epoch 50/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0029 - val_accuracy: 0.9989
# 342/342 [==============================] - 1s 2ms/step
# Overall accuracy of SMOTE - Deep Autoencoder - Convolutional Neural Network model: 0.9989006962257237
# AUC(ROC): 0.9239208217431134
# Precision: 0.8
# Recall: 0.8484848484848485
# F1 score: 0.823529411764706
# False positives: 7
# True positives: 28
# False negatives: 5
# True negatives: 10876
# Fold #2
# After OverSampling, the shape of train_X: (65294, 30)
# After OverSampling, the shape of train_y: (65294,)
#
# After OverSampling, counts of label '1': 32647
# After OverSampling, counts of label '0': 32647
# After OverSampling, the shape of train_X: (65294, 30)
# After OverSampling, the shape of train_y: (65294,)
#
# After OverSampling, counts of label '1': 32647
# After OverSampling, counts of label '0': 32647
# Epoch 1/150
# 1024/1024 [==============================] - 5s 4ms/step - loss: 0.6428 - val_loss: 0.5021
# Epoch 2/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.4767 - val_loss: 0.4382
# Epoch 3/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.4362 - val_loss: 0.4119
# Epoch 4/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.4100 - val_loss: 0.3937
# Epoch 5/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3975 - val_loss: 0.3849
# Epoch 6/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3793 - val_loss: 0.3726
# Epoch 7/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3734 - val_loss: 0.3609
# Epoch 8/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3612 - val_loss: 0.3529
# Epoch 9/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3511 - val_loss: 0.3477
# Epoch 10/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3502 - val_loss: 0.3403
# Epoch 11/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3473 - val_loss: 0.3477
# Epoch 12/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3424 - val_loss: 0.3351
# Epoch 13/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3347 - val_loss: 0.3313
# Epoch 14/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3371 - val_loss: 0.3259
# Epoch 15/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3346 - val_loss: 0.3328
# Epoch 16/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3251 - val_loss: 0.3190
# Epoch 17/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.3217 - val_loss: 0.3164
# Epoch 18/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3207 - val_loss: 0.3152
# Epoch 19/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3176 - val_loss: 0.3254
# Epoch 20/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3198 - val_loss: 0.3106
# Epoch 21/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3156 - val_loss: 0.3112
# Epoch 22/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3112 - val_loss: 0.3116
# Epoch 23/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3132 - val_loss: 0.3039
# Epoch 24/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3087 - val_loss: 0.3119
# Epoch 25/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3178 - val_loss: 0.3060
# Epoch 26/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3052 - val_loss: 0.3075
# Epoch 27/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3043 - val_loss: 0.3266
# Epoch 28/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3095 - val_loss: 0.3041
# Epoch 29/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3016 - val_loss: 0.3003
# Epoch 30/150
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.3019 - val_loss: 0.3007
# Epoch 31/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.3008 - val_loss: 0.3169
# Epoch 32/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3032 - val_loss: 0.2997
# Epoch 33/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2996 - val_loss: 0.3023
# Epoch 34/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3003 - val_loss: 0.2998
# Epoch 35/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3007 - val_loss: 0.3019
# Epoch 36/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3008 - val_loss: 0.3009
# Epoch 37/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2987 - val_loss: 0.3017
# Epoch 38/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.3023 - val_loss: 0.2931
# Epoch 39/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2957 - val_loss: 0.2946
# Epoch 40/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2945 - val_loss: 0.2934
# Epoch 41/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2923 - val_loss: 0.3725
# Epoch 42/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2954 - val_loss: 0.3083
# Epoch 43/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2922 - val_loss: 0.2903
# Epoch 44/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2958 - val_loss: 0.2873
# Epoch 45/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2915 - val_loss: 0.2881
# Epoch 46/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2896 - val_loss: 0.2935
# Epoch 47/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2888 - val_loss: 0.2878
# Epoch 48/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2884 - val_loss: 0.2874
# Epoch 49/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2880 - val_loss: 0.2856
# Epoch 50/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2860 - val_loss: 0.2829
# Epoch 51/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2864 - val_loss: 0.2817
# Epoch 52/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2872 - val_loss: 0.2827
# Epoch 53/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2832 - val_loss: 0.2964
# Epoch 54/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2848 - val_loss: 0.2805
# Epoch 55/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2817 - val_loss: 0.2972
# Epoch 56/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2837 - val_loss: 0.2841
# Epoch 57/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2827 - val_loss: 0.2801
# Epoch 58/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2837 - val_loss: 0.2796
# Epoch 59/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2813 - val_loss: 0.2785
# Epoch 60/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2822 - val_loss: 0.2790
# Epoch 61/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2903 - val_loss: 0.2792
# Epoch 62/150
# 1024/1024 [==============================] - 5s 4ms/step - loss: 0.2821 - val_loss: 0.2780
# Epoch 63/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2810 - val_loss: 0.2761
# Epoch 64/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2799 - val_loss: 0.2804
# Epoch 65/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2830 - val_loss: 0.2788
# Epoch 66/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2790 - val_loss: 0.2799
# Epoch 67/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2811 - val_loss: 0.2757
# Epoch 68/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2793 - val_loss: 0.2796
# Epoch 69/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2812 - val_loss: 0.2865
# Epoch 70/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2779 - val_loss: 0.2819
# Epoch 71/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2787 - val_loss: 0.2774
# Epoch 72/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2783 - val_loss: 0.3248
# Epoch 73/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2842 - val_loss: 0.2787
# Epoch 74/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2801 - val_loss: 0.2800
# Epoch 75/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2843 - val_loss: 0.2908
# Epoch 76/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2818 - val_loss: 0.2766
# Epoch 77/150
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.2775 - val_loss: 0.2788
# Epoch 78/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2770 - val_loss: 0.2760
# Epoch 79/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2770 - val_loss: 0.2870
# Epoch 80/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2828 - val_loss: 0.2742
# Epoch 81/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2783 - val_loss: 0.2817
# Epoch 82/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2826 - val_loss: 0.2755
# Epoch 83/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2750 - val_loss: 0.2747
# Epoch 84/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2739 - val_loss: 0.2737
# Epoch 85/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2755 - val_loss: 0.2724
# Epoch 86/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2777 - val_loss: 0.2772
# Epoch 87/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2793 - val_loss: 0.2744
# Epoch 88/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2736 - val_loss: 0.2708
# Epoch 89/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2740 - val_loss: 0.2720
# Epoch 90/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2757 - val_loss: 0.2702
# Epoch 91/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2718 - val_loss: 0.2689
# Epoch 92/150
# 1024/1024 [==============================] - 5s 4ms/step - loss: 0.2768 - val_loss: 0.2736
# Epoch 93/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2774 - val_loss: 0.2723
# Epoch 94/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2737 - val_loss: 0.2719
# Epoch 95/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2720 - val_loss: 0.2754
# Epoch 96/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2718 - val_loss: 0.2689
# Epoch 97/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2713 - val_loss: 0.2699
# Epoch 98/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2723 - val_loss: 0.2686
# Epoch 99/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2711 - val_loss: 0.2694
# Epoch 100/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2714 - val_loss: 0.2697
# Epoch 101/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2695 - val_loss: 0.2676
# Epoch 102/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2679 - val_loss: 0.2688
# Epoch 103/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2719 - val_loss: 0.2673
# Epoch 104/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2684 - val_loss: 0.2683
# Epoch 105/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2712 - val_loss: 0.2701
# Epoch 106/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2717 - val_loss: 0.2695
# Epoch 107/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2690 - val_loss: 0.2679
# Epoch 108/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2703 - val_loss: 0.2864
# Epoch 109/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2715 - val_loss: 0.2678
# Epoch 110/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2694 - val_loss: 0.2665
# Epoch 111/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2708 - val_loss: 0.2663
# Epoch 112/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2710 - val_loss: 0.2685
# Epoch 113/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2681 - val_loss: 0.2646
# Epoch 114/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2718 - val_loss: 0.2698
# Epoch 115/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2661 - val_loss: 0.2675
# Epoch 116/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2670 - val_loss: 0.2741
# Epoch 117/150
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.2671 - val_loss: 0.3193
# Epoch 118/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2782 - val_loss: 0.2664
# Epoch 119/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2662 - val_loss: 0.2658
# Epoch 120/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2696 - val_loss: 0.2717
# Epoch 121/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2708 - val_loss: 0.2669
# Epoch 122/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2695 - val_loss: 0.2657
# Epoch 123/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2681 - val_loss: 0.2641
# Epoch 124/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2709 - val_loss: 0.2650
# Epoch 125/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2659 - val_loss: 0.2655
# Epoch 126/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2662 - val_loss: 0.2684
# Epoch 127/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2729 - val_loss: 0.2705
# Epoch 128/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2676 - val_loss: 0.2718
# Epoch 129/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2693 - val_loss: 0.2662
# Epoch 130/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2701 - val_loss: 0.2716
# Epoch 131/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2662 - val_loss: 0.2651
# Epoch 132/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2677 - val_loss: 0.2632
# Epoch 133/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2676 - val_loss: 0.2626
# Epoch 134/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2703 - val_loss: 0.2659
# Epoch 135/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2656 - val_loss: 0.2631
# Epoch 136/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2648 - val_loss: 0.2646
# Epoch 137/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2649 - val_loss: 0.2644
# Epoch 138/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2660 - val_loss: 0.2642
# Epoch 139/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2640 - val_loss: 0.2665
# Epoch 140/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2647 - val_loss: 0.2681
# Epoch 141/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2632 - val_loss: 0.2925
# Epoch 142/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2685 - val_loss: 0.2638
# Epoch 143/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2637 - val_loss: 0.2635
# Epoch 144/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2643 - val_loss: 0.2650
# Epoch 145/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2667 - val_loss: 0.2636
# Epoch 146/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2638 - val_loss: 0.2647
# Epoch 147/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2663 - val_loss: 0.2636
# Epoch 148/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2656 - val_loss: 0.2658
# Epoch 149/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2630 - val_loss: 0.2629
# Epoch 150/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2651 - val_loss: 0.2645
# 1024/1024 [==============================] - 1s 1ms/step
# 342/342 [==============================] - 0s 1ms/step
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1024/1024 [==============================] - 7s 5ms/step - loss: 0.2086 - accuracy: 0.9335 - val_loss: 0.0468 - val_accuracy: 0.9970
# Epoch 2/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0586 - accuracy: 0.9922 - val_loss: 0.0149 - val_accuracy: 0.9985
# Epoch 3/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0342 - accuracy: 0.9951 - val_loss: 0.0129 - val_accuracy: 0.9988
# Epoch 4/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0241 - accuracy: 0.9959 - val_loss: 0.0096 - val_accuracy: 0.9986
# Epoch 5/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0228 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9988
# Epoch 6/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0140 - accuracy: 0.9977 - val_loss: 0.0088 - val_accuracy: 0.9987
# Epoch 7/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0145 - accuracy: 0.9972 - val_loss: 0.0090 - val_accuracy: 0.9986
# Epoch 8/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.0079 - val_accuracy: 0.9987
# Epoch 9/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 0.0079 - val_accuracy: 0.9988
# Epoch 10/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.0080 - val_accuracy: 0.9987
# Epoch 11/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.0073 - val_accuracy: 0.9988
# Epoch 12/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0117 - accuracy: 0.9977 - val_loss: 0.0065 - val_accuracy: 0.9988
# Epoch 13/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 0.0068 - val_accuracy: 0.9988
# Epoch 14/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0064 - val_accuracy: 0.9988
# Epoch 15/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0061 - val_accuracy: 0.9988
# Epoch 16/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0091 - accuracy: 0.9978 - val_loss: 0.0063 - val_accuracy: 0.9988
# Epoch 17/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.0059 - val_accuracy: 0.9988
# Epoch 18/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.0049 - val_accuracy: 0.9988
# Epoch 19/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 0.0054 - val_accuracy: 0.9988
# Epoch 20/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.0049 - val_accuracy: 0.9988
# Epoch 21/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 22/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 23/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.0048 - val_accuracy: 0.9988
# Epoch 24/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0049 - val_accuracy: 0.9988
# Epoch 25/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0049 - val_accuracy: 0.9988
# Epoch 26/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0046 - val_accuracy: 0.9989
# Epoch 27/50
# 1024/1024 [==============================] - 8s 8ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0043 - val_accuracy: 0.9988
# Epoch 28/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 29/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0046 - val_accuracy: 0.9991
# Epoch 30/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 31/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 32/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 33/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 34/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 35/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0046 - val_accuracy: 0.9987
# Epoch 36/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0042 - val_accuracy: 0.9987
# Epoch 37/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0041 - val_accuracy: 0.9988
# Epoch 38/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9991
# Epoch 39/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.0044 - val_accuracy: 0.9990
# Epoch 40/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.0043 - val_accuracy: 0.9990
# Epoch 41/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0043 - val_accuracy: 0.9990
# Epoch 42/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0044 - val_accuracy: 0.9991
# Epoch 43/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0043 - val_accuracy: 0.9991
# Epoch 44/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0042 - val_accuracy: 0.9990
# Epoch 45/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.0043 - val_accuracy: 0.9992
# Epoch 46/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9991
# Epoch 47/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.0042 - val_accuracy: 0.9991
# Epoch 48/50
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9992
# Epoch 49/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0043 - val_accuracy: 0.9993
# Epoch 50/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0042 - val_accuracy: 0.9988
# 342/342 [==============================] - 1s 2ms/step
# Overall accuracy of SMOTE - Deep Autoencoder - Convolutional Neural Network model: 0.9988090875778673
# AUC(ROC): 0.9238748785289261
# Precision: 0.7777777777777778
# Recall: 0.8484848484848485
# F1 score: 0.8115942028985507
# False positives: 8
# True positives: 28
# False negatives: 5
# True negatives: 10875
# Fold #3
# After OverSampling, the shape of train_X: (65296, 30)
# ...
# Epoch 74/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2870 - val_loss: 0.3069
# Epoch 75/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2886 - val_loss: 0.3021
# Epoch 76/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2875 - val_loss: 0.3011
# Epoch 77/150
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.2852 - val_loss: 0.3997
# Epoch 78/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2882 - val_loss: 0.3097
# Epoch 79/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2820 - val_loss: 0.3029
# Epoch 80/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2931 - val_loss: 0.2982
# Epoch 81/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2855 - val_loss: 0.3148
# Epoch 82/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2925 - val_loss: 0.3081
# Epoch 83/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2843 - val_loss: 0.2966
# Epoch 84/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2848 - val_loss: 0.2969
# Epoch 85/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2827 - val_loss: 0.2962
# Epoch 86/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2804 - val_loss: 0.2981
# Epoch 87/150
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.2821 - val_loss: 0.3077
# Epoch 88/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2822 - val_loss: 0.2977
# Epoch 89/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2829 - val_loss: 0.2968
# Epoch 90/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2797 - val_loss: 0.2949
# Epoch 91/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2801 - val_loss: 0.3079
# Epoch 92/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2823 - val_loss: 0.3000
# Epoch 93/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2837 - val_loss: 0.2981
# Epoch 94/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2801 - val_loss: 0.2940
# Epoch 95/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2803 - val_loss: 0.2994
# Epoch 96/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2808 - val_loss: 0.2933
# Epoch 97/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2777 - val_loss: 0.2970
# Epoch 98/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2779 - val_loss: 0.2955
# Epoch 99/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2788 - val_loss: 0.2939
# Epoch 100/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2766 - val_loss: 0.2933
# Epoch 101/150
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.2798 - val_loss: 0.2902
# Epoch 102/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2774 - val_loss: 0.2907
# Epoch 103/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2788 - val_loss: 0.2963
# Epoch 104/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2785 - val_loss: 0.2902
# Epoch 105/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2759 - val_loss: 0.2897
# Epoch 106/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2815 - val_loss: 0.2933
# Epoch 107/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2773 - val_loss: 0.3000
# Epoch 108/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2755 - val_loss: 0.2944
# Epoch 109/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2748 - val_loss: 0.2896
# Epoch 110/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2753 - val_loss: 0.2887
# Epoch 111/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2756 - val_loss: 0.2985
# Epoch 112/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2796 - val_loss: 0.2855
# Epoch 113/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2751 - val_loss: 0.2879
# Epoch 114/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2748 - val_loss: 0.2908
# Epoch 115/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2773 - val_loss: 0.2905
# Epoch 116/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2786 - val_loss: 0.2942
# Epoch 117/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2727 - val_loss: 0.3009
# Epoch 118/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2730 - val_loss: 0.2902
# Epoch 119/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2746 - val_loss: 0.2860
# Epoch 120/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2734 - val_loss: 0.2915
# Epoch 121/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2739 - val_loss: 0.2887
# Epoch 122/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2725 - val_loss: 0.2862
# Epoch 123/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2718 - val_loss: 0.2883
# Epoch 124/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2737 - val_loss: 0.2842
# Epoch 125/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2738 - val_loss: 0.2983
# Epoch 126/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2741 - val_loss: 0.2845
# Epoch 127/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2795 - val_loss: 0.2899
# Epoch 128/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2784 - val_loss: 0.2966
# Epoch 129/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2717 - val_loss: 0.2831
# Epoch 130/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2720 - val_loss: 0.2847
# Epoch 131/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2711 - val_loss: 0.2879
# Epoch 132/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2732 - val_loss: 0.2846
# Epoch 133/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2706 - val_loss: 0.2941
# Epoch 134/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2727 - val_loss: 0.2843
# Epoch 135/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2731 - val_loss: 0.2841
# Epoch 136/150
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.2729 - val_loss: 0.2849
# Epoch 137/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2708 - val_loss: 0.2939
# Epoch 138/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2803 - val_loss: 0.2830
# Epoch 139/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2705 - val_loss: 0.2838
# Epoch 140/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2692 - val_loss: 0.2833
# Epoch 141/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2713 - val_loss: 0.2830
# Epoch 142/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2742 - val_loss: 0.2831
# Epoch 143/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2699 - val_loss: 0.2843
# Epoch 144/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2723 - val_loss: 0.2827
# Epoch 145/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2688 - val_loss: 0.3039
# Epoch 146/150
# 1024/1024 [==============================] - 4s 4ms/step - loss: 0.2742 - val_loss: 0.2848
# Epoch 147/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2711 - val_loss: 0.2880
# Epoch 148/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2732 - val_loss: 0.2829
# Epoch 149/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2712 - val_loss: 0.2926
# Epoch 150/150
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.2700 - val_loss: 0.2854
# 1024/1024 [==============================] - 1s 1ms/step
# 342/342 [==============================] - 1s 1ms/step
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1024/1024 [==============================] - 7s 6ms/step - loss: 0.2554 - accuracy: 0.9103 - val_loss: 0.0605 - val_accuracy: 0.9957
# Epoch 2/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0577 - accuracy: 0.9914 - val_loss: 0.0220 - val_accuracy: 0.9978
# Epoch 3/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0351 - accuracy: 0.9949 - val_loss: 0.0150 - val_accuracy: 0.9984
# Epoch 4/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0242 - accuracy: 0.9959 - val_loss: 0.0137 - val_accuracy: 0.9984
# Epoch 5/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0202 - accuracy: 0.9964 - val_loss: 0.0142 - val_accuracy: 0.9983
# Epoch 6/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0161 - accuracy: 0.9974 - val_loss: 0.0122 - val_accuracy: 0.9984
# Epoch 7/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0147 - accuracy: 0.9975 - val_loss: 0.0136 - val_accuracy: 0.9981
# Epoch 8/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0156 - accuracy: 0.9973 - val_loss: 0.0098 - val_accuracy: 0.9986
# Epoch 9/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 0.0101 - val_accuracy: 0.9986
# Epoch 10/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0113 - accuracy: 0.9977 - val_loss: 0.0093 - val_accuracy: 0.9986
# Epoch 11/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0113 - accuracy: 0.9974 - val_loss: 0.0082 - val_accuracy: 0.9986
# Epoch 12/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0105 - accuracy: 0.9978 - val_loss: 0.0074 - val_accuracy: 0.9986
# Epoch 13/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.0073 - val_accuracy: 0.9986
# Epoch 14/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0101 - accuracy: 0.9980 - val_loss: 0.0069 - val_accuracy: 0.9986
# Epoch 15/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.0074 - val_accuracy: 0.9986
# Epoch 16/50
# 1024/1024 [==============================] - 7s 6ms/step - loss: 0.0079 - accuracy: 0.9981 - val_loss: 0.0077 - val_accuracy: 0.9985
# Epoch 17/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0067 - val_accuracy: 0.9986
# Epoch 18/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0089 - accuracy: 0.9981 - val_loss: 0.0066 - val_accuracy: 0.9986
# Epoch 19/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 0.0062 - val_accuracy: 0.9986
# Epoch 20/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.0066 - val_accuracy: 0.9986
# Epoch 21/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.0062 - val_accuracy: 0.9986
# Epoch 22/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0060 - val_accuracy: 0.9986
# Epoch 23/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0060 - val_accuracy: 0.9986
# Epoch 24/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.0061 - val_accuracy: 0.9986
# Epoch 25/50
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0062 - val_accuracy: 0.9986
# Epoch 26/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0066 - val_accuracy: 0.9986
# Epoch 27/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0064 - val_accuracy: 0.9986
# Epoch 28/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0058 - val_accuracy: 0.9986
# Epoch 29/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0062 - val_accuracy: 0.9986
# Epoch 30/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0061 - val_accuracy: 0.9986
# Epoch 31/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0056 - val_accuracy: 0.9986
# Epoch 32/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0058 - val_accuracy: 0.9985
# Epoch 33/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0059 - val_accuracy: 0.9985
# Epoch 34/50
# 1024/1024 [==============================] - 7s 6ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.0058 - val_accuracy: 0.9985
# Epoch 35/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0056 - val_accuracy: 0.9985
# Epoch 36/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0056 - val_accuracy: 0.9985
# Epoch 37/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0057 - val_accuracy: 0.9985
# Epoch 38/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.0055 - val_accuracy: 0.9985
# Epoch 39/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0056 - val_accuracy: 0.9985
# Epoch 40/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0056 - val_accuracy: 0.9986
# Epoch 41/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0055 - val_accuracy: 0.9986
# Epoch 42/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0055 - val_accuracy: 0.9986
# Epoch 43/50
# 1024/1024 [==============================] - 7s 6ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0055 - val_accuracy: 0.9986
# Epoch 44/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0054 - val_accuracy: 0.9986
# Epoch 45/50
# 1024/1024 [==============================] - 6s 5ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0054 - val_accuracy: 0.9987
# Epoch 46/50
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0054 - val_accuracy: 0.9988
# Epoch 47/50
# 1024/1024 [==============================] - 6s 6ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0055 - val_accuracy: 0.9987
# Epoch 48/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0053 - val_accuracy: 0.9987
# Epoch 49/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0054 - val_accuracy: 0.9988
# Epoch 50/50
# 1024/1024 [==============================] - 5s 5ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0053 - val_accuracy: 0.9989
# 342/342 [==============================] - 1s 2ms/step
# Overall accuracy of SMOTE - Deep Autoencoder - Convolutional Neural Network model: 0.9989006962257237
# AUC(ROC): 0.9261489561823627
# Precision: 0.8055555555555556
# Recall: 0.8529411764705882
# F1 score: 0.8285714285714286
# False positives: 7
# True positives: 29
# False negatives: 5
# True negatives: 10875

# %%
print(" Average tn = " + str(Average(tn_summary)))
print(" Average fp = " + str(Average(fp_summary)))
print(" Average fn = "+ str(Average(fn_summary)))    
print(" Average tp = "+ str(Average(tp_summary)))   


Average_precision = Average(tp_summary)/(Average(tp_summary)+Average(fp_summary))
Average_recall = Average(tp_summary)/(Average(tp_summary)+Average(fn_summary))
Average_f1_score = 2*Average_precision*Average_recall/(Average_precision + Average_recall)

print(" Average Precision = " + str(Average_precision))

print(" Average Recall = " + str(Average_recall))

print(" Average F1 score = " + str(Average_f1_score))
# Out:
#  Average tn = 10874.25
#  Average fp = 8.25
#  Average fn = 5.0
#  Average tp = 28.5
#  Average Precision = 0.7755102040816326
#  Average Recall = 0.8507462686567164
#  Average F1 score = 0.8113879003558719

# %%
total_tn=0
total_fp=0
total_fn=0
total_tp=0

for i in tn_summary:
    total_tn = total_tn + i

for j in fp_summary:
    total_fp = total_fp + j
    
for x in fn_summary:
    total_fn = total_fn + x
    
for y in tp_summary:
    total_tp = total_tp + y

print(" Total tn: " + str(total_tn))
print(" Total fp: " + str(total_fp))
print(" Total fn: " + str(total_fn))
print(" Total tp: " + str(total_tp))


Total_Precision = total_tp/(total_tp + total_fp)
Total_Recall = total_tp/(total_tp+ total_fn)

Total_F1_score = 2*Total_Precision*Total_Recall/(Total_Precision + Total_Recall)

print(" Total Precision = " + str(Total_Precision))
print(" Total Recall = " + str(Total_Recall))
print(" Total F1_score = " + str(Total_F1_score))
# Out:
#  Total tn: 43497
#  Total fp: 33
#  Total fn: 20
#  Total tp: 114
#  Total Precision = 0.7755102040816326
#  Total Recall = 0.8507462686567164
#  Total F1_score = 0.8113879003558719

# %%
print("--- %s seconds ---" % (time.time() - start_time))

Total_time = (time.time()-start_time)

print(Total_time)
# Out:
# --- 3412.6869661808014 seconds ---
# 3412.6890318393707

# %%
Total_time_hours = Total_time/3600

print(Total_time_hours)
# Out:
# 0.9479691755109363

# %%
df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 10389  16740  1.415995 -0.907739 -0.301174 -1.470941  0.986286  3.808803
# 6954    9038 -0.576646  0.363052  0.799349 -0.540667 -0.242577  1.244138
# 22873  32480 -0.725206  1.084868  2.322993  1.754984  0.243857  0.142478
# 25869  33805 -1.307883 -0.436816  1.305069 -0.907667  2.796423  3.853829
# 21160  31509  1.063223 -0.009382  1.511183  1.536151 -0.995627  0.002168
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 10389 -1.819840  0.924006  1.048866  ...  0.104326  0.476588 -0.127697
# 6954   1.243837 -0.129046  1.484877  ... -0.239558 -0.174614 -0.160003
# 22873  0.206068  0.117883 -0.922247  ...  0.083631  0.154456 -0.209804
# 25869 -0.010319  0.676115  0.382027  ...  0.023453  0.331993 -0.129014
# 21160 -0.581854  0.167600  0.703414  ...  0.007391  0.276120  0.084210
#
#             V24       V25       V26       V27       V28  Amount  Class
# 10389  0.996122  0.594930 -0.069912  0.025877  0.012507   10.00    0.0
# 6954  -1.274918  0.116972  1.138171 -0.069934 -0.032686  235.63    0.0
# 22873 -0.131248 -0.260219 -0.103805  0.015832  0.120330    4.00    0.0
# 25869  1.005012  0.716656 -0.383583 -0.349626 -0.339349   55.60    0.0
# 21160  0.618209  0.281883 -0.398251  0.091408  0.041979   12.00    0.0
#
# [5 rows x 31 columns]
